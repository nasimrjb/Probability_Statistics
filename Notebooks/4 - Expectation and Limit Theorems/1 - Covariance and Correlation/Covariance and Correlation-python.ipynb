# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br>
# 			<br>
# پاییز ۱۳۹۸
# 		</div>
# 		<hr/>
# 		<font color=red size=6>
# 			<br>
# 			<center>کوواریانس و هم‌بستگی</center>
# 		</font>
# 		<br>
# 		<center>شبنم شیخها، امیرحسین کریمی</center>
# 		<hr>
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
# 				<li>
#                     <a href="#sec_intro">
#                         مقدمه
#                     </a>
#                 </li>
#                 <li>
# 					<a href="#sec_cov">
#                         کوواریانس
#                             <ul style="margin-right: 0;">
#                                 <li>
#                                     <a href="#sec_reminder">
#                                         یادآوری
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_cov_meaning">
#                                         معنای کوواریانس
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_cov_vis">
#                                         فهم بهتر کوواریانس به کمک تصویرسازی
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_cov_more_vis">
#                                         بیشتر درک کنید، مستطیل‌های رنگی
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_cov_disc_cont">
#                                         محاسبه‌ی کوواریانس در متغیرهای تصادفی گسسته و پیوسته
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_cov_attr">
#                                         ویژگی‌های کوواریانس
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_example">
#                                         مثال: مرد خوشحال
#                                     </a>
#                                 </li>
#                             </ul>
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_corr">
#                         هم‌بستگی
#                             <ul style="margin-right: 0;">
#                                 <li>
#                                     <a href="#sec_corr_meaning">
#                                         معنای هم‌بستگی
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_corr_attr">
#                                         ویژگی‌های هم‌بستگی
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#sec_corr_cause">
#                                         هم‌بستگی و علیت
#                                     </a>
#                                 </li>
#                             </ul>
#                     </a>
# 				</li>
#                 <li>
#                     <a href="#sec_end">
#                         خلاصه و نتیجه‌گیری
#                     </a>
#                 </li>
#                 <li>
#                     <a href="#sec_ref">
#                         منابع
#                     </a>
#                 </li>
# 			</ul>
# 		</div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_intro" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6.5>
#         مقدمه
#         </font>
# 		<p></p>
# 		<hr>
#         به ارتباط بین جفت متغیرهای تصادفی زیر بیاندیشید:
#         <br />
#         <ul style="margin-right: 0;">
#                                 <li>
#                                         نمره‌ی ریاضی و نمره‌ی علوم یک سری دانش‌آموز
#                                 </li>
#                                 <li>
#                                         قد انسان‌ها و اندازه‌ی شعاع دور سرشان
#                                 </li>
#                                 <li>
#                                          جمعیت یک شهر و میزان آلودگی آن
#                                 </li>
#                                 <li>
#                                          ارزش سهام شرکت اپل و تعداد سیب‌های فروش رفته
#                                 </li>
#                                 <li>
#                                          میزان شارژ باتری لپتاپ و تعداد اپلیکیشن‌های در حال اجرا
#                                 </li>
#                                 <li>
#                                          گل‌های زده‌شده توسط یک بازیکن فوتبال در فصل‌های مختلف و سن او در آن فصل‌ها
#                                 </li>
#                                 <li>
#                                          قیمت دلار و تعداد پراید‌های پیش‌خرید‌شده در سایت سایپا
#                                 </li>
#                                 <li>
#                                          دمای هوا و تعداد بستنی‌‌های فروش‌ رفته
#                                 </li>
#                             </ul>
#         <br />
#         همانطور که احتمالا به صورت شهودی متوجه شدید، بعضی از این موارد ارتباط مثبت، بعضی منفی و بعضی دیگر هیچ ارتباطی با هم ندارند.
#         <br />
# 	correlation (همبستگی) و covariance (هم‌وردایی!) معیاری ریاضی از این ارتباط است.
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_cov" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=7>
# 		<font color=red size=6>
#             <hr>
# 			<div align=center>
# کوواریانس
#             </div>
# 		</font>
# 		<hr>
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_reminder" style="direction:rtl;line-height:300%;">
#     <br>
#     <font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# یادآوری
#         </font>
# 		<p></p>
#         <hr>
#         واریانس در یک متغیر تصادفی را به یاد آورید. قصد داشتیم میزان تغییر یک متغیر تصادفی نسبت به میانگینش را به دست آوریم. برای این کار ابتدا اختلاف هر مشاهده با میانگین را حساب کردیم. با جمع زدن این اختلافات به مقدار صفر رسیدیم. برای رفع این مشکل مجذور اختلافات را با هم جمع کرده و میانگین گرفتیم.
#         <br> <br>
#         	فرمول واریانس به صورت زیر بود:
#             <br>
#             $$Var(X) = E[(X - \mu_X)^2] = E[X^2] - \mu_X^2$$
#     </font>
# </div>

# %% [markdown]
# <div id="sec_cov_meaning" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# معنای کوواریانس
#         </font>
# 		<p></p>
#         <hr>
#         با توجه به اینکه واژه‌ی co به معنای «هم» است، کوواریانس را با استفاده از معنی واریانس معنی می‌کنیم. کوواریانس میزان تغییر دو متغیر با همدیگر نسبت به میانگینشان است.
#         	فرمول کوواریانس به صورت زیر است:
#             <br><br>
#             $$Cov(X,Y) = E[(X - \mu_X)(Y - \mu_Y)]$$
#             <br>
#             <font color=#2c7 size=5><b>تمرین.</b></font>
#             سعی کنید اثبات کنید$$Cov(X, Y) = E[XY] - \mu_x.\mu_y$$
#             هم‌چنین با کمی دقت متوجه می‌شوید که $$Cov(X, X) = Var(X)$$
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_cov_vis" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         فهم بهتر کوواریانس به کمک تصویرسازی
#         </font>
# 		<p></p>
#         <hr>
# داده‌ی weight-height در قسمت منابع، شامل قد و وزن ۱۰هزار نفر است. به نمودار زیر از این داده‌ها توجه کنید:
# </font>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

weight_height = pd.read_csv("res/weight-height.csv")
mH = weight_height['Height'].mean()
mW = weight_height['Weight'].mean()

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(x='Weight', y='Height', data=weight_height, alpha=0.6, s=5)

ax.axhline(mH, color='red', linestyle='--')
ax.axvline(mW, color='blue', linestyle='--')

ax.text(75, mH + 0.5, 'E[Height]', color='red', va='center')
ax.text(mW - 5, 77, 'E[Weight]', color='blue', rotation=90, va='center')

ax.set_xlabel('Weight')
ax.set_ylabel('Height')
ax.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# <br>بیشتر نقطه‌ها در این نمودار، در مربع بالا سمت راست و پایین سمت چپ قرار دارند. در اولی، X و Y هر دو بیشتر از میانگینشان هستند. در دومی نیز هر دو کمتر هستند.
# به عبارتی در اکثر نقاط، اگر X بالاتر از میانگینش باشد Y نیز بالاتر از میانگین خود و اگر X پایین‌تر باشد Y نیز پایین‌تر است.
# </font>
# </div>

# %% [markdown]
# <div id="sec_cov_more_vis" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
#         <font color=#FF7500 size=6>بیشتر درک کنید، مستطیل‌های رنگی</font>
#         <hr>
#         <font color=grey><i>**خواندن این بخش اختیاری است، اما درک بهتری نسبت به کوواریانس به شما می‌دهد.</i></font>
#         <br> <br>
#         یکی دیگر از راه‌های تصویر‌سازی کوواریانس که به فهم بهتر آن نیز کمک می‌کند استفاده از مستطیل‌های رنگی است.
#         <br>
#         	فرض کنید دو متغیر تصادفی $X$ و $Y$ داریم. اگر مانند قسمت قبل، نمودار پراکندگی این دو متغیر تصادفی را رسم کنیم، هر جفت نقطه در این نمودار می‌تواند نمایانگر یک مستطیل باشد.
#     <br>
#     اگر نقاط به صورت زیر قرار گرفته باشند با هم‌دیگر رابطه‌ی مثبت دارند (با افزایش یکی، دیگری نیز افزایش می‌یابد) :
#     <br>
#     <img src="res/positive.png" style="float:center; width:20%"/>
#     <br>
#     اگر نقاط به صورت زیر قراره گرفته باشند با هم‌دیگر رابطه‌ی منفی دارند (با افزایش یکی، دیگری کاهش می‌یابد) :
#         <br>
#     <img src="res/negative.png" style="float:center; width:20%"/>
#     <br>
#     حال همه‌ی جفت نقاط را در نظر بگیرید و متناظر با هر کدام یک مستطیل بکشید و مطابق بالا آنها را رنگ کنید. اگر دو ناحیه با رنگ مخالف روی هم قرار بگیرند، رنگ ناحیه سفید (خنثی) می‌شود و اگر دو ناحیه هم‌رنگ روی هم قرار بگیرند، آن ناحیه یک درجه پررنگ تر می‌شود.
#     <br>
#     اگر در نهایت رنگ نمودار بیشتر مایل به قرمز بود، یعنی رابطه‌ی کلی منفی و اگر بیشتر مایل به سبز بود یعنی رابطه‌ی کلی مثبت است. اگر هر دو رنگ به یک اندازه‌ مشاهده می‌شوند یعنی رابطه‌ای وجود ندارد.
#     <br> <br>
#     نمودار زیر از دو متغیر مستقل از هم که از توزیع نرمال پیروی می‌کنند به دست آمده است:
#     <br>
#         <img src="res/rect_chart.png" style="float:center; width:40%"/>
#  	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# با توجه به نکات گفته شده، حال میتوانیم عدد کوواریانس را تا حدی تفسیر کنیم:
# <ul>
#             <li>
#              بیشتر از صفر: مقادیر بالاتر از میانگین $X$ هم‌زمان با مقادیر بالاتر از میانگین $Y$ اتفاق می‌افتد و برعکس
#              (معادل با حالتی که رنگ نمودار مایل به سبز است، یا نمودار پراکندگی مانند نمودار اول می‌شود.)
#             </li>
#             <li>
# اطراف صفر: رابطه‌ای خطی بین تغییر $X$ و $Y$ نسبت به میانگینشان مشاهده نمی‌شود.
# (معادل با حالتی که هر دو رنگ به یک اندازه مشاهده می‌شوند یا نمودار پراکندگی شکل خاصی به خود نمی‌گیرد.)
#             </li>
#             <li>
#             کمتر از صفر: مقادیر بالاتر از میانگین $X$ هم‌زمان با مقادیر پایین‌تر از میانگین $Y$ اتفاق می‌افتد و برعکس.
# (معادل با حالتی که رنگ نمودار مایل به قرمز است یا حالتی که نمودار پراکندگی تقریبا عمود بر نمودار اول است)
#             </li>
#         </ul>
#     </font>
# </div>

# %% [markdown]
# <div id="sec_cov_disc_cont" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
#         <font color=#FF7500 size=6>
#  محاسبه‌ی کوواریانس در متغیرهای تصادفی گسسته و پیوسته
#         </font>
#         <p></p>
#         <hr>
#         فهمیدیم که کوواریانس دو متغیر تصادفی، در واقع امیدریاضی تابعی از آن دو است. با در نظر گرفتن این نکته، به دو گزاره‌ی زیر توجه کنید:
#         <br>
#         <ul><li>
#         اگر دو متغیر تصادفی گسسته‌ی $X$ و $Y$ دارای توزیع توأم $p(x,y)$ باشند آنگاه کوواریانس آن دو مطابق زیر محاسبه می‌شود:
#             </li></ul>
#         $$Cov(X,Y) = \sum_{i=1}^{n} \sum_{j=1}^{m} p(x_i, y_j)(x_i -\mu_X)(y_j - \mu_Y) = \Big(\sum_{i=1}^{n} \sum_{j=1}^{m} p(x_i, y_j)x_iy_j \Big)~-~ \mu_X\mu_Y$$
#    <ul><li>
# اگر دو متغیر تصادفی پیوسته‌ی $X$ و $Y$ بر روی بازه‌ی $[a, b] \times [c,d]$ دارای توزیع توأم $f(x, y)$ باشند آنگاه کوواریانس آن دو مطابق زیر محاسبه می‌شود:
# </ul></li>
#     $$Cov(X, Y) = \int_c^d \int_a^b (x - \mu_x)\,(y - \mu_y)\,f(x,y) \,\mathrm{d}x\mathrm{d}y = \int_c^d \int_a^b x\,y\,f(x,y) \,\mathrm{d}x\mathrm{d}y - \mu_x\mu_y$$
#    </font>
#    <br>
# </div>

# %% [markdown]
# <br>
# <div id="sec_cov_disc_cont" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <font color=blue size=6>مثال.</font>
#         <br>
#         دو متغیر تصادفی X و Y به صورت زیر تعریف شده‌اند:
#         $$X \sim U(-1,\,1)$$
#         $$Y = X^2$$
#         <br>
#         می‌خواهیم کوواریانس این دو را به‌دست آوریم. در واقع باید عبارت زیر را محاسبه کنیم:
#         <br>
#         $$Cov(X, Y) = E[XY] - E[X]E[Y] = E[X.X^2] - E[X]E[X^2] = E[X^3] - E[X]E[X^2]$$
#         <br>
#          اگر $X$ یک متغیر تصادفی با توزیع یکنواخت در محدوده‌ی $[a, b]$ باشد داریم:
#          $$E[X] = \int_a^bx.f(x)\,\mathrm{d}x = \int_a^bx.\frac{1}{b - a}\,\mathrm{d}x = \frac{x^2}{2\,(b - a)}\big|_{x = a}^{x = b} = \frac{b + a}{2}$$
#          <br>
#          $$E[X^2] = \int_a^bx^2.f(x)\,\mathrm{d}x = \int_a^bx^2.\frac{1}{b - a}\,\mathrm{d}x = \frac{x^3}{3\,(b - a)}\big|_{x = a}^{x = b} = \frac{b^3 - a^3}{3\,(b - a)}$$
#          <br>
#          $$E[X^3] = \int_a^bx^3.f(x)\,\mathrm{d}x = \int_a^bx^3.\frac{1}{b - a}\,\mathrm{d}x = \frac{x^4}{4\,(b - a)}\big|_{x = a}^{x = b} = \frac{b^4 - a^4}{4\,(b - a)}$$
#          <br>
#          با توجه به روابط بالا می‌توانیم عبارات زیر را بدست آوریم:
#          <br>
#          $$E[X] = 0 \quad \quad \quad  E[X^2] = \frac{1}{3} \quad  \quad \quad E[X^3] = 0$$
#          <br>
#          با جایگذاری در رابطه‌ی اول می‌رسیم به اینکه $Cov(X,Y) = 0$
#          <br><br>         پس دیدیم با اینکه متغیر تصادفی های $X$ و $Y$ به هم وابسته بودند، حاصل کوواریانس آنها صفر شد. این را در R نیز تست می‌کنیم. با استفاده از دستور runif مشاهده‌هایی از متغیر تصادفی $X$ و سپس با استفاده از آنها مشاهده‌هایی از $Y$ را تولید می‌کنیم. در نهایت با استفاده از دستور cov کوواریانس آن دو را بدست می‌آوریم:
# </div>

# %%
import numpy as np

X = np.random.uniform(low=-1, high=1, size=10000)
Y = X ** 2
covariance = np.cov(X, Y)[0, 1]

print(f"Covariance between X and Y: {covariance:.4f}")
# Out:
# Covariance between X and Y: -0.0031

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# همانطور که میبینید کوواریانس بسیار نزدیک به صفر شد.
# <br/>
# <font color=blue size=5>
# کنجکاوی.
#         </font>
#                 چرا مقدار آن دقیقا صفر نشد؟
#                 <br>
#     تمرین. ۱۰۰ بار این عمل را در R انجام دهید و میانگین کوواریانس های بدست آمده را محاسبه کنید. تعداد دفعات را به ۱۰۰۰ بار افزایش دهید. سپس ۱۰۰۰۰ بار. میانگین‌ها را مقایسه کنید.
#     </font>
# </div>

# %% [markdown]
# <div id="sec_cov_attr" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>ویژگی‌های کوواریانس</font>
# 		<p></p>
#         <hr>
#         چند مورد از ویژگی‌های کوواریانس را در زیر آورده‌ایم:
#         <br><br>
#         $1. \quad Cov(X_1 + X_2\,,Y) = Cov(X_1\,,Y) + Cov(X_2\,,Y) \\
#         2. \quad Cov(aX + b\,,cY + d) = acCov(X\,,Y) \\
#         3. \quad Var(X + Y) = Var(X) + Var(Y) + 2Cov(X\,,Y) \\
#         \quad 3.1. \quad Var\Big(\sum_{i = 1}^nX_i\Big) = \sum_{i = 1}^n\sum_{j = 1}^nCov(X_i\,,X_j) =
# \sum_{i = 1}^nVar\big(X_i\big) + 2\sum_{(i, j): i < j}Cov(X_i\,, X_j) \\
#         4. \quad if~X~and~Y~are~independent~then~Cov(X\,,Y) = 0$
#         <br><br>
# 		<font color=red size=6><b>تذکر مهم.</b></font>
#         دقت کنید که برعکس مورد ۴ صادق نیست. یعنی صرفا صفر بودن کوواریانس دو متغیر تصادفی بیانگر استقلال آنها از هم نیست.
#         <br>
#         <font color=red size=6>تذکر.</font>
#         با استفاده از موارد ۳ و ۴ میتوان دید که اگر دو متغیر تصادفی مستقل از هم باشند، واریانس جمع‌شان برابر با جمع واریانس‌هایشان می‌باشد.
#         <br> <br>
#         مورد ۲ را اثبات می‌کنیم:
#         <br>
#         $Cov(aX + b\,, cY + d) = E[(aX + b)(cY + d)] - E[aX + b]E[cY + d] = E[acXY + adX + bcY + bd] - (aE[X] + b)(cE[Y] + d) = acE[XY] + adE[X] + bcE[Y] + bd - acE[X]E[Y] - adE[X] - bcE[Y] - bd = acE[XY] - acE[X]E[Y] = ac(E[XY] - E[X]E[Y]) = acCov(X,Y)
# $
#         <br> <br>
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <font color=#2c7 size=5><b>تمرین ۱.</b></font>
#         سعی کنید سایر ویژگی‌ها را نیز به صورت تئوری اثبات کنید.
#         <br>
#         <font color=#2c7 size=5><b>تمرین ۲.</b></font>
#         ثابت کنید که در صورتی‌ که $X$ و $Y$ دو متغیر تصادفی و $n$ عددی ثابت باشند اگر داشته باشیم $X + Y = n$ آن‌گاه $Cov(X\,,Y) = -Var(X)$
#         <br>
#         راهنمایی.  از ویژگی ۲ استفاده کنید.
#         <br>
#         <font color=#2c7 size=5><b>تمرین ۳.</b></font>
#         اگر $X$ و $Y$ دو متغیر تصادفی با واریانس برابر باشند، ثابت کنید $X + Y$ و $X - Y$ دارای کوواریانس صفر هستند.
#     </font>
# </div>

# %% [markdown]
# <div id="sec_example" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" color=#FF7500 size=6>
# مثال: مرد خوشحال
# 	</font>
#     <hr>
# 	<font face="XB Zar" size=5>
#     مرد خوشحالی روی مرکز صفحه‌ی مختصات (0,0) ایستاده و در هر مرحله یک واحد با احتمال برابر به یکی از جهت‌های شمال، جنوب، شرق یا غرب حرکت می‌کند.
#     <br>
#     متغیر تصادفی‌های $(X_n,Y_n)$ و $R_n$ را به ترتیب موقعیت او در صفحه‌ی مختصات و فاصله‌ی او از مرکز مختصات پس از $n$ مرحله در نظر بگیرید.
#     <br>
#     الف. تعیین کنید که آیا $X_n$ و $Y_n$ از هم مستقل هستند یا خیر؟
#     <br>
#       ب. $Cov(X_n,Y_n)$ را بیابید.
#         <br>
#     پ. $E[R_n^2]$ را بیابید.
#         <br>
#     <br>
#     <font color=blue size=5>
#     پاسخ.
#     </font>
#         برای اینکه نشان دهیم $X_n$ و $Y_n$ از هم مستقل نیستند، یک مثال حداکثری میزنیم. اگر فرض کنیم مرد خوشحال در همه‌ی مراحل به سمت شرق حرکت کرده باشد، می‌توان نتیجه گرفت حتما $Y_n=0$ است. این یعنی $Pr(Y_n = 0|X_n = n) = 1$.
#     <br><br>
#     توجه کنید $X_n$ و $Y_n$ را می‌توان به صورت زیر نوشت:
#     $$X_n = \sum_{i=1}^n H_i \quad , \quad Y_n = \sum_{j=1}^n V_j$$
#     به طوری که $H_i$ جهت حرکت در مرحله‌ی $i$اُم روی محور xها را نشان می‌دهد؛ حرکت به سمت غرب $-1$، حرکت به سمت شرق $1$ و در غیر اینصورت $0$ است. $V_j$ به طور مشابه حرکت روی محور yها را نشان می‌دهد. طبق ویژگی‌های کوواریانس می‌توان $Cov(X_n,Y_n)$ را به صورت زیر نوشت:
#     $$Cov(\sum_{i=1}^n H_i , \sum_{j=1}^n V_j) = \sum_{i=1}^n \sum_{j=1}^n Cov(H_i,V_j)$$
#     در حالتی که $i \neq j$، $H_i$ و $V_j$ از هم مستقل‌اند و حاصل کوواریانسشان صفر است. اما $H_i$ و $V_i$ به هم شدیدا وابسته‌اند. در واقع حتما یکی از آنها صفر است، یعنی $Cov(H_i,V_i) = E[H_iV_i] - E[H_i]E[V_i] = 0$. پس:
#     $$Cov(X_n,Y_n) = \sum_{i,j}Cov(H_i,V_j) = 0.$$
#     از آنجایی که برای $i \neq j$، $H_i$ و $H_j$ از هم مستقل‌اند پس کوواریانس آنها صفر است:
#     $$Cov(H_i,H_j) = 0 \quad \rightarrow \quad E[H_iH_j] - E[H_i]E[H_j] = 0 \quad \rightarrow \quad E[H_iH_j] = 0$$
#     با داشتن روابط $R_n^2 = X_n^2 + Y_n^2$ و $E[H_iH_j] = 0$ برای $i \neq j$ و کمی تقارن، نتیجه می‌گیریم:
#     $$E[R_n^2] = E[X_n^2] + E[Y_n^2] = 2E[X_n^2] = 2nE[H_1^2] = n$$
#     </font>
# </div>

# %% [markdown]
# <div id="sec_corr" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#     <hr>
# 		<font color=red size=6>
# 			<div align=center>
# هم‌بستگی
#             </div>
# 		</font>
# 	<hr>
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_corr_meaning" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# معنای هم‌بستگی
#         </font>
# 		<p></p>
#         <hr>
#         در قسمت قبل که از کوواریانس حرف زدیم، صرفا به علامت آن توجه کردیم و نه به مقدار آن. در واقع مقدار آن هیچ اطلاعاتی به ما نمی‌دهد.
#         <br>
#         واحد کوواریانس، واحد متغیر $X$ در واحد متغیر $Y$ است. از روی فرمول $Cov(X,Y) = E[XY] - \mu_X \mu_Y$ هم می‌توان این را حدس زد. به همین دلیل اگر ما صرفا واحد‌های متغیر‌ها را تغییر بدهیم، عدد کوواریانس نیز تغییر خواهد کرد.
# <br>
# مثلا نسبت قد و وزن انسان‌ها را در نظر بگیرید. فرض کنید یک بار قد را بر حسب سانتی‌متر و یک بار بر حسب متر نوشته‌ایم. در حالت اول کوواریانس صد برابر حالت دوم خواهد شد، در حالی که تغییر قد و وزن نسبت به همدیگر تفاوتی نکرده‌است.
#         <br>
#         برای رفع این مشکل هم‌بستگی را تعریف می‌کنیم.
#         <br><br>
#         متغیر $X$ و $Y$ را استاندارد میکنیم:
#     $$X \rightarrow \frac{X - \mu_X}{\sigma_X} \quad \quad Y \rightarrow \frac{Y - \mu_Y}{\sigma_Y} $$
#     <br>
#     حال کوواریانس این دو متغیر استاندارد‌شده را در نظر بگیرید. (دقت کنید که میانگین صفر شده است):
#     <br> <br>
# $$ Cov(\frac{X - \mu_X}{\sigma_X}, \frac{Y - \mu_Y}{\sigma_Y}) =
#     E[\frac{X - \mu_X}{\sigma_X} \frac{Y - \mu_Y}{\sigma_Y}] =
# \frac{1}{\sigma_X\sigma_Y}E[(X - \mu_X)(Y - \mu_Y)] =
# \frac{Cov(X, Y)}{\sigma_X\sigma_Y}$$
# <br>
# واضح است که در کسر نهایی، واحد صورت و مخرج یکسان است. پس مشکل مقیاس که بالاتر مطرح کردیم را نداریم.
# <br>
# مقدار $\frac{Cov(X,~Y)}{\sigma_X\sigma_Y}$ را هم‌بستگی یا $\rho$ می‌نامیم.
# </font>
# </div>

# %% [markdown]
# <div id="sec_corr_attr" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# خواص هم‌بستگی
#         </font>
#         <hr>
#         <br>
#     بعضی از خواص هم‌بستگی عبارتند از:
#     <ul>
#     <li> هم‌بستگی مقیاس ندارد. یعنی اگر مقداری را در $X$ یا $Y$ ضرب کنیم، مقدار هم‌بستگی تغییر نخواهد کرد.</li>
#     <li> هم‌بستگی دو متغیر تصادفی مستقل از هم برابر با صفر است. </li>
#     <li> $ -1 \leq \rho \leq 1$</li>
#     </ul>
#     خاصیت آخر مهم‌ترین خاصیت هم‌بستگی است. هرچقدر مقدار هم‌بستگی به $1$ یا $-1$ نزدیک‌تر باشد، میزان رابطه‌ی خطی $X$ و $Y$ نیز (مثبت یا منفی) افزایش می‌یابد.
#     همچنین داریم:
#     <br> <br>
#     $$
#     \rho = +1  \iff  Y = aX + b, ~ a > 0 \\
#     \rho = -1 \iff Y = aX + b, ~ a < 0
#     $$
#     <br>
#    	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <font color=#2c7 size=5><b>تمرین ۱.</b></font>
#             سعی کنید دو رابطه‌ی بالا را اثبات کنید.
#             <br>
#             راهنمایی: عبارات $Var(\frac{X}{\sigma_X} \pm \frac{Y}{\sigma_Y})$
#             را در نظر بگیرید.
#             <br>
#         <font color=#2c7 size=5><b>تمرین ۲.</b></font>
#         عبارت $Cov(X,Y)^2 \le Var(X)Var(Y)$ یکی از صورت‌های نامساوی کوشی-شوارتز است. با استفاده از آن ثابت کنید هم‌بستگی همواره بین $-1$ و $1$ است.
# </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         در زیر، نمودار دو متغیر تصادفی با هم‌بستگی دلخواه را مشاهده میکنید. برای تغییر مقدار هم‌بستگی، خط سوم را تغییر دهید. همچنین مفید است که بدانید هم‌بستگی بزرگتر از $0.7$ یا کوچکتر از $-0.7$، هم‌بستگی قوی محسوب می‌شود.
# </font>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

corr = 0.7
points = 4000

x = np.random.normal(0, 1, points)
n = np.random.normal(0, 1, points)

if corr != 0:
    numerator = np.sqrt((1 - corr**2)/corr**2) - 1
    denominator = (1 - 2*corr**2)/corr**2
    a = numerator / denominator
else:
    a = 0
    
b = 1 - a
sign = -1 if corr < 0 else 1
y = sign * (a*x + b*n)

plt.figure(figsize=(8, 8))
plt.scatter(x, y, s=0.6, color='blue', alpha=0.6)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <br>
#         <font color=#2c7 size=5><b>تمرین عملی.</b></font>
# دیتاست `human.csv` واقع در پوشه‌ی res را بخوانید و هم‌بستگی ستون‌های مختلف آن را بدست آورید. هم‌بستگی در `R` با استفاده از دستور `cor()` محاسبه می‌شود.
# <br>
# بخش اختیاری.
# تلاش کنید correlation map برای ستون‌های داده رسم کنید.
#     </font>
# </div>

# %% [markdown]
# <div id="sec_corr_cause" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
#         <font color=#FF7500 size=6>
# هم‌بستگی و علیت
#         </font>
#         <hr>
#         <br>
# حال که معنای هم‌بستگی را یاد گرفتید شاید به ذهنتان برسد که اگر دو متغیر $X$ و $Y$ هم‌بستگی مثبت داشته باشند، یعنی افزایش یکی <b>موجب</b> افزایش دیگری می‌شود.
# ولی این تفکر درستی نیست.
# <br> <br>
# <center><b>هم‌بستگی به معنای علیت نیست</b></center>
# <br>
# مثلا فرض کنید $X$ متغیر تصادفی تعداد بستنی‌های فروخته شده و $Y$ تعداد حمله‌های کوسه‌ها در هر ماه باشد. اگر هم‌بستگی این دو مثبت باشد، دلیل بر این نمی‌شود که فروش زیاد بستنی‌ها موجب حمله‌ی کوسه بشود.
# احتمالا فروش زیاد بستنی به علت گرمی هوا بوده، و در هوای گرم تعداد افراد کنار ساحل و داخل دریا بیشتر می‌شود و بدین ترتیب حمله‌ي کوسه‌ها نیز افزایش می‌یابد.
# <br>
# </font>
# </div>

# %% [markdown]
# <div id="sec_end" style="direction:rtl;line-height:300%;">
#     <br>
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# خلاصه و نتیجه‌گیری
#         </font>
# 		<p></p>
# 		<hr>
#         در این بخش با موارد زیر در رابطه با کوواریانس و هم‌بستگی آشنا شدیم:
#         <ul>
#             <li>
#             کوواریانس به معنای این است که دو متغیر تصادفی چقدر با هم دیگر نسبت به میانگینشان تغییر می‌کنند.
#             </li>
#             <li>
#             کوواریانس دو متغیر تصادفی مستقل از هم برابر با صفر است ولی عکس این مورد لزوما درست نیست.
#             </li>
#             <li>
#            واحد کوواریانس به واحد داده‌ها ربط دارد و بدین ترتیب نمی‌توانیم مقدار کوواریانس را مقایسه کنیم و تنها علامت آن برای ما اهمیت دارد.
#             </li>
#             <li>
#             برای رفع این مشکل، هم‌بستگی را تعریف کردیم که عددی بدون واحد و در بازه ی 1- و 1 است.
#             </li>
#             <li>
#             هم‌بستگی به معنای علیت نیست.
#             </li>
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_ref" style="direction:rtl;line-height:300%;">
#     <br>
#     <font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# منابع
#         </font>
# 		<p></p>
# 		<hr>
#         <ul>
#             <li>
#                 <a href="https://ocw.mit.edu/courses/mathematics/18-05-introduction-to-probability-and-statistics-spring-2014/readings/MIT18_05S14_Reading7b.pdf">Jeremy Orloff, and Jonathan Bloom. 18.05 Introduction to Probability and Statistics. Spring 2014. Massachusetts Institute of Technology: MIT OpenCourseWare</a>
#             </li>
#             <li>
#                 <a href="https://ocw.mit.edu/courses/sloan-school-of-management/15-063-communicating-with-data-summer-2003/lecture-notes/lecture8.pdf">John Carroll. 15.063 Communicating With Data. Summer 2003. Massachusetts Institute of Technology: MIT OpenCourseWare</a>
#             </li>
#             <li>
#                 <a href="https://math.stackexchange.com/questions/1040298/covariance-of-uniform-distribution-and-its-square">https://math.stackexchange.com/questions/1040298/covariance-of-uniform-distribution-and-its-square</a>
#             </li>
#             <li>
#                 <a href="https://www.dummies.com/education/math/business-statistics/how-covariance-and-correlation-are-related/">https://www.dummies.com/education/math/business-statistics/how-covariance-and-correlation-are-related/</a>
#             </li>
#             <li>
#                 <a href="https://stats.stackexchange.com/questions/18058/how-would-you-explain-covariance-to-someone-who-understands-only-the-mean">https://stats.stackexchange.com/questions/18058/how-would-you-explain-covariance-to-someone-who-understands-only-the-mean</a>
#             </li>
#             <li>
#                 <a href="http://www.davidchudzicki.com/posts/covariance-as-signed-area-of-rectangles/">http://www.davidchudzicki.com/posts/covariance-as-signed-area-of-rectangles/</a>
#             </li>
#             <li>
#                 <a href="http://www.randomservices.org/random/expect/Covariance.html">http://www.randomservices.org/random/expect/Covariance.html</a>
#             </li>
#             <li>
#                 <a href="https://keydifferences.com/difference-between-covariance-and-correlation.html">https://keydifferences.com/difference-between-covariance-and-correlation.html</a>
#             </li>
#             <li>
#                 <a href="http://www.preservearticles.com/201107189322/what-are-the-main-properties-of-correlation.html">http://www.preservearticles.com/201107189322/what-are-the-main-properties-of-correlation.html</a>
#             </li>
#             <li>
#                 <a href="https://projects.iq.harvard.edu/files/stat110/files/final_exam.pdf">https://projects.iq.harvard.edu/files/stat110/files/final_exam.pdf</a>
#             </li>
#         </ul>
# 	</font>
# </div>
